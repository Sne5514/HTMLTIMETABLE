# %% [markdown]
# # HTML Time Table

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <h1>TIME TABLE</h1>
#
#      <table border="1" cellspacing="5" cellpadding="10">
#         <tr>
#             <th bgcolor="red">Day</th>
#             <th bgcolor="red">1</th>
#             <th bgcolor="red">2</th>
#             <th bgcolor="red">3</th>
#             <th bgcolor="gree">Break</th>
#             <th bgcolor="red">4</th>
#             <th bgcolor="red">5</th>
#             <th bgcolor="red">6</th>
#             <th bgcolor="red">7</th>
#         </tr>
#
#         <tr>
#             <td bgcolor="red">Time</td>
#             <td bgcolor="yellow">8.30-9.10</td>
#             <td bgcolor="yellow">9.10-9.50</td>
#             <td bgcolor="yellow">9.50-10.30</td>
#             <td bgcolor="gree">10.30-10.50</td>
#             <td bgcolor="yellow">10.50-11.30</td>
#             <td bgcolor="yellow">11.30-12.05</td>
#             <td bgcolor="yellow">12.05-12-40</td>
#             <td bgcolor="yellow">12.40-1.15</td>
#         </tr>
#
#         <tr>
#             <td bgcolor="red">Monday</td>
#             <td>Hindi</td>
#             <td>Language Skill</td>
#             <td>Math</td>
#             <td rowspan="6" bgcolor="gree">Break</td>
#             <td>Computer</td>
#             <td>Sports</td>
#             <td>GK</td>
#             <td>History</td>
#         </tr>
#
#         <tr>
#             <td bgcolor="red">Tuesday</td>
#             <td>Number Work</td>
#             <td>KYS</td>
#             <td>Computer</td>
#             <td>Sports</td>
#             <td>Language Skill</td>
#             <td>Hindi</td>
#             <td>Art</td>
#         </tr>
#
#         <tr>
#             <td bgcolor="red">Wednesday</td>
#             <td>Math</td>
#             <td>Hindi</td>
#             <td>English</td>
#             <td>Computer</td>
#             <td>Music</td>
#             <td>Environmental Studies</td>
#             <td>Reading</td>
#         </tr>
#
#         <tr>
#             <td bgcolor="red">Thursday</td>
#             <td>Language Skill</td>
#             <td>Sports</td>
#             <td>Hindi</td>
#             <td>Reading</td>
#             <td>KYS</td>
#             <td>Number Work</td>
#             <td>Geography</td>
#         </tr>
#
#         <tr>
#             <td bgcolor="red">Friday</td>
#             <td>English</td>
#             <td>Hindi</td>
#             <td>Math</td>
#             <td>Computer Science</td>
#             <td>Social Studies</td>
#             <td>Language Skill</td>
#             <td>Art</td>
#         </tr>
#
#         <tr>
#             <td bgcolor="red">Saturday</td>
#             <td>GK</td>
#             <td>Art</td>
#             <td>Computer</td>
#             <td>Number Work</td>
#             <td>Art</td>
#             <td>Geography</td>
#             <td>History</td>
#         </tr>
#
#
#  </table>
#
# </body>
# </html>
